# %% [markdown]
# Colab Link: https://colab.research.google.com/drive/1tzrtNRrcwQJQEZQ9utRZUTgXKvBtwFOm

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = "cs231n-project"
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %%
import os
import torch
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

from PIL import Image, ImageOps

# %%
dataset_path = f"/content/drive/My Drive/cs231n-project/dataset/Taskent"

# %%
from image_dataset import *
taskent_dataset = PetroDataset(dataset_path)
# Out:
# __init__ PetroDataset with: /content/drive/My Drive/cs231n-project/dataset/Taskent

# %%
taskent_subimage_dataset = PetroSubImageDataset(dataset_path)
# Out:
# __init__ PetroSubImageDataset: /content/drive/My Drive/cs231n-project/dataset/Taskent
#          , sub_image_size=480
#          , image_indices=None
# __init__ BaseSubImageDataset with: /content/drive/My Drive/cs231n-project/dataset/Taskent/img
#          , sub_image_size=480
#          , image_indices=None
#          , mask=False
# __init__ BaseSubImageDataset with: /content/drive/My Drive/cs231n-project/dataset/Taskent/masks_machine
#          , sub_image_size=480
#          , image_indices=None
#          , mask=True

# %%
print(len(taskent_dataset))
print(len(taskent_subimage_dataset))
# Out:
# 21
# 1008

# %%
img,mask = taskent_subimage_dataset[0]

# %%
img
# Out:
# array([[[125, 125, 125],
#         [132, 132, 132],
#         [140, 140, 140],
#         ...,
#         [132, 132, 132],
#         [115, 115, 115],
#         [113, 113, 113]],
#
#        [[133, 133, 133],
#         [135, 135, 135],
#         [131, 131, 131],
#         ...,
#         [129, 129, 129],
#         [115, 115, 115],
#         [113, 113, 113]],
#
#        [[122, 122, 122],
#         [122, 122, 122],
#         [120, 120, 120],
#         ...,
#         [134, 134, 134],
#         [123, 123, 123],
#         [115, 115, 115]],
#
#        ...,
#
#        [[134, 134, 134],
#         [136, 136, 136],
#         [126, 126, 126],
#         ...,
#         [148, 148, 148],
#         [148, 148, 148],
#         [151, 151, 151]],
#
#        [[133, 133, 133],
#         [128, 128, 128],
#         [121, 121, 121],
#         ...,
#         [158, 158, 158],
#         [157, 157, 157],
#         [162, 162, 162]],
#
#        [[136, 136, 136],
#         [137, 137, 137],
#         [139, 139, 139],
# ...

# %%
mask
# Out:
# array([[2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        [1, 1, 1, ..., 2, 2, 2],
#        ...,
#        [1, 1, 1, ..., 2, 2, 2],
#        [1, 1, 1, ..., 2, 2, 2],
#        [1, 1, 1, ..., 2, 2, 2]], dtype=uint8)

# %%
ImageOps.autocontrast(Image.fromarray(mask).convert('L'))
# Out:
# <PIL.Image.Image image mode=L size=480x480>
